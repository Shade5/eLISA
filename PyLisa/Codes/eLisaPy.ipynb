# %%
from mpl_toolkits.mplot3d import Axes3D
import math as m
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.figure()
for i in range(10):
    plt.plot([i], [i], marker='o', markersize=3, color="red")

# %%
fig = plt.figure()
ax = Axes3D(fig)

x=np.arange(0,2*m.pi,0.01);
y1=np.sin(x);
y2=np.cos(x);
y3=np.sin(x);



     # make a new figure
plt.hold(True)

# put 0s on the y-axis, and put the y axis on the z-axis
for i in range(np.size(y1)):
    ax.plot([i],[i],[i], marker='o', markersize=3, color="red")
    
    
plt.show()
