# %%
from mpl_toolkits.mplot3d import Axes3D
import math as m
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.hold(True)
plt.show()
for i in range(10):
    plt.plot([i], [i], marker='o', markersize=3, color="red")

# %%
fig = plt.figure()
ax = Axes3D(fig)

x=np.arange(0,2*m.pi,0.01);
y1=np.sin(x);
y2=np.cos(x);
y3=np.sin(x);
plt.hold(True)
plt.show()
# put 0s on the y-axis, and put the y axis on the z-axis
for i in range(np.size(y1)):
    ax.plot(0,0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-179a0643af8f> in <module>()
#      10 # put 0s on the y-axis, and put the y axis on the z-axis
#      11 for i in range(np.size(y1)):
# ---> 12     ax.plot(0,0,0)
#      13
#      14
#
# /home/elsy/workspace/PyLisa/env/lib/python3.5/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, *args, **kwargs)
#    1537         # Match length
#    1538         if not cbook.iterable(zs):
# -> 1539             zs = np.ones(len(xs)) * zs
#    1540
#    1541         lines = Axes.plot(self, xs, ys, *args[argsi:], **kwargs)
#
# TypeError: object of type 'int' has no len()
